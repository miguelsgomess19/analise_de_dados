# %% [markdown]
# ## Analise de hábitos e notas de estudantes
# Notebook criado para realizar analises e previsões de notas em exames escolares com base em *hábitos* e *caracteres* de estudanes.
# - Bibliotecas utilizados: Pandas 🐼 e Seaborn 🤖

# %% [markdown]
# import pandas as pd: Importa a biblioteca Pandas, que é o "canivete suíço" do Python para manipulação de dados tabulares. O as pd é um apelido (alias) padrão da comunidade para não termos que digitar "pandas" toda vez.
#
# import seaborn as sns: Importa o Seaborn, uma biblioteca de visualização de dados focada em gráficos estatísticos atraentes.
#
# pd.read_csv(...): Lê o arquivo CSV contendo os dados brutos e o transforma em um DataFrame (uma tabela de dados em memória) armazenado na variável df.

# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv(r".\data\dataset_aula03_student_habits_performance.csv")

# %% [markdown]
# df.head(): Retorna as 5 primeiras linhas do DataFrame. Serve para você bater o olho e ver se os dados carregaram corretamente (nomes das colunas, formatação básica).
#
# df.tail(): Retorna as 5 últimas linhas. Útil para verificar como o dataset termina e confirmar o número total de registros exibidos no índice.

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %% [markdown]
# df.info(): Este é um dos comandos mais cruciais. Ele fornece um resumo técnico do DataFrame:
#
# Quantidade total de linhas (1000 entries).
#
# Quantidade de colunas.
#
# O tipo de dado de cada coluna (ex: float64 para números decimais, int64 para inteiros, object para texto/strings).
#
# Contagem de valores não nulos (Non-Null Count): É aqui que o analista percebe se há dados faltando (missing values).

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
# ...

# %% [markdown]
# .isna(): Varre a coluna e retorna True (1) se o dado estiver vazio (NaN) e False (0) se estiver preenchido.
#
# .sum(): Soma os valores True. O resultado deu 15, significando que há 15 alunos sem o nível de escolaridade dos pais preenchido.

# %%
df["parental_education_level"].isna().sum()
# Out:
# np.int64(91)

# %%
df["parental_education_level"].notnull().sum()
# Out:
# np.int64(909)

# %%
df["parental_education_level"] = df ["parental_education_level"].fillna("Desconhecido")

# %%
df["parental_education_level"].isna().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   str
#  12  internet_quality               1000 non-null   str
# ...

# %%
df["parental_education_level"].unique()
# Out:
# <ArrowStringArray>
# ['Master', 'High School', 'Bachelor', 'Desconhecido']
# Length: 4, dtype: str

# %%
df["parental_education_level"].nunique()
# Out:
# 4

# %%
colunas = [
    "age",
    "study_hours_per_day",
    "social_media_hours",
    "netflix_hours",
    "attendance_percentage",
    "sleep_hours",
    "exercise_frequency",
    "mental_health_rating",
    "exam_score"
    ]

# %%
sns.heatmap(data=df[colunas].corr(), annot=True, cmap="coolwarm",fmt=".2f");

# %%
sns.lmplot(data=df,x="study_hours_per_day", y= "exam_score")

# %%
sns.lmplot(data=df,x="netflix_hours", y= "exam_score")

# %%
sns.lmplot(data=df,x="study_hours_per_day", y= "mental_health_rating")

# %%
filtro_horas_altas = df["study_hours_per_day"] >= 5 
filtro_horas_baixas = df["study_hours_per_day"] < 2 

media_alta = df[filtro_horas_altas]["exam_score"].mean()
media_baixa =df[filtro_horas_baixas]["exam_score"].mean()

print(f"A média que estudaram 5 ou mais horas {media_alta:.2f}")
print(f"Já a média, das pessoas que estudaram menos de que 2 horas foi {media_baixa:.2f}")
# Out:
# A média que estudaram 5 ou mais horas 90.30
# Já a média, das pessoas que estudaram menos de que 2 horas foi 45.56
